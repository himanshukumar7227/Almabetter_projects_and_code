# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ## About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
# link to the cleaned [dataset](https://drive.google.com/file/d/1n7AqsxFtZMg6JHDmP_pnDyLA3gkJG_kE/view?usp=drive_link)
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ## Importing impotent libraries for this data analysis.

# %%
#importing the the libraries.
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## loading dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/AlmabetterProjects/applied Statistics/Midcorse_assignment/Data.csv")

# %% [markdown]
# ## Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.head(10)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
# 5   7348        1958         PhD         Single  71691.0        0         0
# 6   4073        1954    2n Cycle        Married  63564.0        0         0
# 7   1991        1967  Graduation       Together  44931.0        0         1
# 8   4047        1954         PhD        Married  65324.0        0         1
# 9   9477        1954         PhD        Married  65324.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain'],
#       dtype='object')

# %%
df.shape
# Out:
# (2240, 22)

# %%
df['Dt_Customer'].value_counts()['########']
# Out:
# 916

# %%
df=df[df["Dt_Customer"].str.contains("#")==False]

# %%
df.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 13
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %%
df['Dt_Customer']=pd.to_datetime(df['Dt_Customer'])

# %%
listr=np.array(df['Year_Birth'].astype(str))
for i in range(len(listr)):
    listr[i]='01-01-'+listr[i]
print(listr)
df['Year_Birth']=listr
# Out:
# ['01-01-1970' '01-01-1961' '01-01-1958' ... '01-01-1973' '01-01-1977'
#  '01-01-1978']

# %%
df['Year_Birth']=pd.to_datetime(df['Year_Birth'])

# %%
# finding the actual age at the time of enrolment of the customer.
df['Age'] = (df['Dt_Customer'] - df['Year_Birth']).dt.days / 365.25  # Account for leap years
df['Age'] = df['Age'].round(0)  # Round to the nearest whole year

# %%
df.head()
# Out:
#       Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826 1970-01-01  Graduation       Divorced  84835.0        0         0
# 1      1 1961-01-01  Graduation         Single  57091.0        0         0
# 2  10476 1958-01-01  Graduation        Married  67267.0        0         1
# 5   7348 1958-01-01         PhD         Single  71691.0        0         0
# 6   4073 1954-01-01    2n Cycle        Married  63564.0        0         0
#
#   Dt_Customer  Recency  MntWines  ...  MntSweetProducts  MntGoldProds  \
# 0  2014-06-16        0       189  ...               189           218
# 1  2014-06-15        0       464  ...                 0            37
# 2  2014-05-13        0       134  ...                 2            30
# 5  2014-03-17        0       336  ...                32            43
# 6  2014-01-29        0       769  ...                34            65
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1311 entries, 0 to 2238
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1311 non-null   int64
#  1   Year_Birth           1311 non-null   datetime64[ns]
#  2   Education            1311 non-null   object
#  3   Marital_Status       1311 non-null   object
#  4   Income               1311 non-null   float64
#  5   Kidhome              1311 non-null   int64
#  6   Teenhome             1311 non-null   int64
#  7   Dt_Customer          1311 non-null   datetime64[ns]
#  8   Recency              1311 non-null   int64
#  9   MntWines             1311 non-null   int64
#  10  MntFruits            1311 non-null   int64
#  11  MntMeatProducts      1311 non-null   int64
#  12  MntFishProducts      1311 non-null   int64
#  13  MntSweetProducts     1311 non-null   int64
#  14  MntGoldProds         1311 non-null   int64
# ...

# %%
df.shape
# Out:
# (1311, 23)

# %%
df.describe()
# Out:
#                  Id                     Year_Birth         Income  \
# count   1311.000000                           1311    1311.000000
# mean    5447.928299  1968-09-10 08:18:40.366132720   51429.747521
# min        1.000000            1893-01-01 00:00:00    1730.000000
# 25%     2735.000000            1959-01-01 00:00:00   35541.000000
# 50%     5231.000000            1970-01-01 00:00:00   50447.000000
# 75%     8205.500000            1977-01-01 00:00:00   68211.000000
# max    11188.000000            1996-01-01 00:00:00  157146.000000
# std     3233.235292                            NaN   20960.186407
#
#            Kidhome     Teenhome                    Dt_Customer      Recency  \
# count  1311.000000  1311.000000                           1311  1311.000000
# mean      0.435545     0.501907  2013-07-19 10:34:52.448512512    49.302059
# min       0.000000     0.000000            2012-07-30 00:00:00     0.000000
# ...

# %%
df.to_csv("hero.csv")

# %% [markdown]
# ## Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# ## measures of central tendency

# %%
#importing important libraries
import statistics as stats

# %%
df.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain', 'Age'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1311 entries, 0 to 2238
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1311 non-null   int64
#  1   Year_Birth           1311 non-null   datetime64[ns]
#  2   Education            1311 non-null   object
#  3   Marital_Status       1311 non-null   object
#  4   Income               1311 non-null   float64
#  5   Kidhome              1311 non-null   int64
#  6   Teenhome             1311 non-null   int64
#  7   Dt_Customer          1311 non-null   datetime64[ns]
#  8   Recency              1311 non-null   int64
#  9   MntWines             1311 non-null   int64
#  10  MntFruits            1311 non-null   int64
#  11  MntMeatProducts      1311 non-null   int64
#  12  MntFishProducts      1311 non-null   int64
#  13  MntSweetProducts     1311 non-null   int64
#  14  MntGoldProds         1311 non-null   int64
# ...

# %%
# mean of key variables income, kidhome, Recenncy,MntWines, MntFruits, MntMeatProducts,
# MntFishProducts, NumDealsPurchases, MntGoldProds,MntSweetProducts, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases,
# NumStorePurchases, NumWebVisitsMonth, Response, Complain
listOfKeyVlu=['Income', 'Kidhome',
       'Teenhome', 'Recency', 'MntWines', 'MntFruits',
       'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
       'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
       'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
       'Response', 'Complain','Age']
dict_of_mean={}
for e in listOfKeyVlu:
    if e not in dict_of_mean:
        dict_of_mean[e]=stats.mean(df[e])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-d4585b1ec960> in <cell line: 11>()
#      11 for e in listOfKeyVlu:
#      12     if e not in dict_of_mean:
# ...

# %%
#importing important libraries
import statistics as stats

# mean of key variables income, kidhome, Recenncy,MntWines, MntFruits, MntMeatProducts,
# MntFishProducts, NumDealsPurchases, MntGoldProds,MntSweetProducts, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases,
# NumStorePurchases, NumWebVisitsMonth, Response, Complain
listOfKeyVlu=['Income', 'Kidhome',
       'Teenhome', 'Recency', 'MntWines', 'MntFruits',
       'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
       'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
       'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
       'Response', 'Complain'] # Removed 'Age' from the list
dict_of_mean={}
for e in listOfKeyVlu:
    if e not in dict_of_mean:
        dict_of_mean[e]=stats.mean(df[e])

# Check if 'Age' or a similar column exists in your DataFrame
print(df.columns)
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain', 'Age'],
#       dtype='object')

# %%
#mean of keyValues.
for key,value in dict_of_mean.items():
    print(f"Mean of {key}: {value}")
# Out:
# Mean of Income: 51429.74752097635
# Mean of Kidhome: 0.43554538520213576
# Mean of Teenhome: 0.501906941266209
# Mean of Recency: 49.30205949656751
# Mean of MntWines: 302.8070175438597
# Mean of MntFruits: 25.255530129672007
# Mean of MntMeatProducts: 162.71700991609458
# Mean of MntFishProducts: 36.47139588100686
# Mean of MntSweetProducts: 26.922959572845155
# Mean of MntGoldProds: 43.87490465293669
# Mean of NumDealsPurchases: 2.3173150266971776
# Mean of NumWebPurchases: 4.081617086193745
# Mean of NumCatalogPurchases: 2.594965675057208
# Mean of NumStorePurchases: 5.794050343249428
# Mean of NumWebVisitsMonth: 5.410373760488177
# Mean of Response: 0.15179252479023647
# Mean of Complain: 0.009153318077803204

# %%
# mediean
dict_of_median={}
for e in listOfKeyVlu:
    if e not in dict_of_median:
        dict_of_median[e]=stats.median(df[e])
#median of keyValues.
for key,value in dict_of_median.items():
    print(f"Median of {key}: {value}")
# Out:
# Median of Income: 50447.0
# Median of Kidhome: 0
# Median of Teenhome: 0
# Median of Recency: 50
# Median of MntWines: 171
# Median of MntFruits: 7
# Median of MntMeatProducts: 66
# Median of MntFishProducts: 11
# Median of MntSweetProducts: 8
# Median of MntGoldProds: 25
# Median of NumDealsPurchases: 2
# Median of NumWebPurchases: 4
# Median of NumCatalogPurchases: 1
# Median of NumStorePurchases: 5
# Median of NumWebVisitsMonth: 6
# Median of Response: 0
# Median of Complain: 0

# %%
# mode of response and complain
dict_of_mode={}
for e in listOfKeyVlu:
    if e not in dict_of_mode:
        dict_of_mode[e]=stats.mode(df[e])
#mode of keyValues.
for key,value in dict_of_mode.items():
    print(f"Mode of {key}: {value}")
# Out:
# Mode of Income: 7500.0
# Mode of Kidhome: 0
# Mode of Teenhome: 0
# Mode of Recency: 65
# Mode of MntWines: 2
# Mode of MntFruits: 0
# Mode of MntMeatProducts: 11
# Mode of MntFishProducts: 0
# Mode of MntSweetProducts: 0
# Mode of MntGoldProds: 3
# Mode of NumDealsPurchases: 1
# Mode of NumWebPurchases: 1
# Mode of NumCatalogPurchases: 0
# Mode of NumStorePurchases: 3
# Mode of NumWebVisitsMonth: 7
# Mode of Response: 0
# Mode of Complain: 0

# %% [markdown]
# ## measures of dispersion (variance, standard deviation)

# %%
# Variance
dict_of_variance={}
for e in listOfKeyVlu:
    if e not in dict_of_variance:
        dict_of_variance[e]=stats.variance(df[e])
#mode of keyValues.
for key,value in dict_of_variance.items():
    print(f"variance of {key}: {value}")
# Out:
# variance of Income: 439329414.19803774
# variance of Kidhome: 0.281147774847008
# variance of Teenhome: 0.2944620096540721
# variance of Recency: 829.5880797247017
# variance of MntWines: 115035.48104995313
# variance of MntFruits: 1492.0117537454655
# variance of MntMeatProducts: 48275.8397028083
# variance of MntFishProducts: 2966.9531888133874
# variance of MntSweetProducts: 1684.4910068067613
# variance of MntGoldProds: 2713.657621651207
# variance of NumDealsPurchases: 3.5999976709114305
# variance of NumWebPurchases: 7.340661810516999
# variance of NumCatalogPurchases: 8.02895173546212
# variance of NumStorePurchases: 10.690376788303317
# variance of NumWebVisitsMonth: 5.921541157906383
# variance of Response: 0.12884983783720835
# variance of Complain: 0.00907645815501249

# %%
dict_of_std={}
for e in listOfKeyVlu:
    if e not in dict_of_std:
        dict_of_std[e]=stats.stdev(df[e])
#mode of keyValues.
for key,value in dict_of_std.items():
    print(f"Standard deviation of {key}: {value}")
# Out:
# Standard deviation of Income: 20960.18640656704
# Standard deviation of Kidhome: 0.5302336983321675
# Standard deviation of Teenhome: 0.5426435382956957
# Standard deviation of Recency: 28.80257071382174
# Standard deviation of MntWines: 339.16880907588353
# Standard deviation of MntFruits: 38.62656797782409
# Standard deviation of MntMeatProducts: 219.71763630352547
# Standard deviation of MntFishProducts: 54.46974562831542
# Standard deviation of MntSweetProducts: 41.042551173224616
# Standard deviation of MntGoldProds: 52.092778978004304
# Standard deviation of NumDealsPurchases: 1.897365982332199
# Standard deviation of NumWebPurchases: 2.709365573435412
# Standard deviation of NumCatalogPurchases: 2.833540494763066
# Standard deviation of NumStorePurchases: 3.2696141650511787
# Standard deviation of NumWebVisitsMonth: 2.4334216975087535
# Standard deviation of Response: 0.3589565960352426
# Standard deviation of Complain: 0.09527044743787283

# %% [markdown]
# ## outliers detection

# %%
#ploting histogram for knowing the skuwness or for outlier detection of data so that I can choose mean or mediean accordinglly.
for e in listOfKeyVlu:
    sns.histplot(df[e],bins=25,kde=True)
    plt.show()

# %%
#To see outliers properly using boxplot.
listOfKeyVlu2=['Income', 'Kidhome',
       'Teenhome', 'Recency', 'MntWines', 'MntFruits',
       'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
       'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
       'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
       'Age']
for e in listOfKeyVlu2:
    print(f"Box plot of {e}")
    sns.boxplot(df[e])
    plt.show()
# Out:
# Box plot of Income
# Box plot of Kidhome
# Box plot of Teenhome
# Box plot of Recency
# Box plot of MntWines
# Box plot of MntFruits
# Box plot of MntMeatProducts
# Box plot of MntFishProducts
# Box plot of MntSweetProducts
# Box plot of MntGoldProds
# Box plot of NumDealsPurchases
# Box plot of NumWebPurchases
# Box plot of NumCatalogPurchases
# Box plot of NumStorePurchases
# Box plot of NumWebVisitsMonth
# Box plot of Age

# %%
# upper and lower limit lists for data.
#finding limits.
upper_limit_list=[]
lower_limit_list=[]
for e in listOfKeyVlu:
    upper_limit_list.append(df[e].mean()+3*df[e].std())
    lower_limit_list.append(df[e].mean()-3*df[e].std())
for i in range(len(upper_limit_list)):
    print(f"upper limit of {e} : ",upper_limit_list[i])
    print(f"lower limit {e} : ",lower_limit_list[i])
    print('\n')
# Out:
# upper limit of Complain :  114310.30674067748
# lower limit Complain :  -11450.811698724778
#
#
# upper limit of Complain :  2.026246480198638
# lower limit Complain :  -1.1551557097943665
#
#
# upper limit of Complain :  2.129837556153296
# lower limit Complain :  -1.1260236736208782
#
#
# upper limit of Complain :  135.70977163803275
# lower limit Complain :  -37.10565264489772
#
#
# upper limit of Complain :  1320.3134447715104
# lower limit Complain :  -714.6994096837909
#
#
# upper limit of Complain :  141.13523406314425
# lower limit Complain :  -90.62417380380025
#
#
# upper limit of Complain :  821.869918826671
# lower limit Complain :  -496.43589899448176
#
#
# upper limit of Complain :  199.88063276595315
# lower limit Complain :  -126.93784100393944
#
#
# upper limit of Complain :  150.050613092519
# lower limit Complain :  -96.2046939468287
#
#
# upper limit of Complain :  200.15324158694963
# lower limit Complain :  -112.40343228107625
#
#
# ...

# %%
#finding the outliers.
list2=range(len(upper_limit_list))
for i in range(len(upper_limit_list)):
    temp1=listOfKeyVlu[i]
    print(df.loc[(df[temp1]>upper_limit_list[i])|(df[temp1]<lower_limit_list[i])])
# Out:
#          Id Year_Birth   Education Marital_Status    Income  Kidhome  \
# 325    4931 1977-01-01  Graduation       Together  157146.0        0
# 1925  11181 1949-01-01         PhD        Married  156924.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntSweetProducts  \
# 325          0  2013-04-29       13         1  ...                 1
# 1925         0  2013-08-29       85         2  ...                 1
#
#       MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 325              1                  0                0                   28
# 1925             1                  0                0                    0
#
#       NumStorePurchases  NumWebVisitsMonth  Response  Complain   Age
# 325                   0                  1         0         0  36.0
# 1925                  0                  0         0         0  65.0
#
# [2 rows x 23 columns]
# Empty DataFrame
# ...

# %%
# Triming the outliers data
new_df=df
for i in range(len(upper_limit_list)):
    temp1=listOfKeyVlu[i]
    print("old Data before removing outliers : ",len(new_df))
    new_df=new_df.loc[(new_df[temp1]<upper_limit_list[i])&(new_df[temp1]>lower_limit_list[i])]
    print("New Data after removing outliers: ",len(new_df))
    print("\n")
print("Old data: ",len(df))
print("New data: ",len(new_df))
print("Total outliers removal: ",len(df)-len(new_df))
# Out:
# old Data before removing outliers :  1311
# New Data after removing outliers:  1309
#
#
# old Data before removing outliers :  1309
# New Data after removing outliers:  1309
#
#
# old Data before removing outliers :  1309
# New Data after removing outliers:  1309
#
#
# old Data before removing outliers :  1309
# New Data after removing outliers:  1309
#
#
# old Data before removing outliers :  1309
# New Data after removing outliers:  1301
#
#
# old Data before removing outliers :  1301
# New Data after removing outliers:  1266
#
#
# old Data before removing outliers :  1266
# New Data after removing outliers:  1245
#
#
# old Data before removing outliers :  1245
# New Data after removing outliers:  1218
#
#
# old Data before removing outliers :  1218
# New Data after removing outliers:  1195
#
#
# old Data before removing outliers :  1195
# New Data after removing outliers:  1181
#
#
# old Data before removing outliers :  1181
# New Data after removing outliers:  1163
#
#
# ...

# %%
#ploting histogram for knowing the skuwness or for outlier detection of data so that I can choose mean or mediean accordinglly.
for e in listOfKeyVlu:
    sns.histplot(new_df[e],bins=25,kde=True)
    plt.show()

# %%
new_df.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain', 'Age'],
#       dtype='object')

# %%
#To see outliers properly using boxplot.
for e in listOfKeyVlu2:
    print(f"Box plot of {e}")
    sns.boxplot(np.array(new_df[e]))
    plt.show()
# Out:
# Box plot of Income
# Box plot of Kidhome
# Box plot of Teenhome
# Box plot of Recency
# Box plot of MntWines
# Box plot of MntFruits
# Box plot of MntMeatProducts
# Box plot of MntFishProducts
# Box plot of MntSweetProducts
# Box plot of MntGoldProds
# Box plot of NumDealsPurchases
# Box plot of NumWebPurchases
# Box plot of NumCatalogPurchases
# Box plot of NumStorePurchases
# Box plot of NumWebVisitsMonth
# Box plot of Age

# %%
# mean
dict_of_mean={}
for e in listOfKeyVlu:
    if e not in dict_of_mean:
        dict_of_mean[e]=stats.mean(new_df[e])
#mean of keyValues.
for key,value in dict_of_mean.items():
    print(f"Mean of {key}: {value}")
# Out:
# Mean of Income: 48749.74019180471
# Mean of Kidhome: 0.4742807323452485
# Mean of Teenhome: 0.5265911072362686
# Mean of Recency: 49.39755884917175
# Mean of MntWines: 269.8526591107236
# Mean of MntFruits: 18.612031386224935
# Mean of MntMeatProducts: 126.3182214472537
# Mean of MntFishProducts: 26.65387968613775
# Mean of MntSweetProducts: 19.734960767218833
# Mean of MntGoldProds: 36.957279860505665
# Mean of NumDealsPurchases: 2.289450741063644
# Mean of NumWebPurchases: 3.931996512641674
# Mean of NumCatalogPurchases: 2.223190932868352
# Mean of NumStorePurchases: 5.547515257192677
# Mean of NumWebVisitsMonth: 5.578901482127288
# Mean of Response: 0.13077593722755013
# Mean of Complain: 0

# %%
# mediean
dict_of_median={}
for e in listOfKeyVlu:
    if e not in dict_of_median:
        dict_of_median[e]=stats.median(new_df[e])
#median of keyValues.
for key,value in dict_of_median.items():
    print(f"Median of {key}: {value}")
# Out:
# Median of Income: 46910.0
# Median of Kidhome: 0
# Median of Teenhome: 1
# Median of Recency: 50
# Median of MntWines: 125
# Median of MntFruits: 6
# Median of MntMeatProducts: 51
# Median of MntFishProducts: 10
# Median of MntSweetProducts: 6
# Median of MntGoldProds: 20
# Median of NumDealsPurchases: 2
# Median of NumWebPurchases: 3
# Median of NumCatalogPurchases: 1
# Median of NumStorePurchases: 4
# Median of NumWebVisitsMonth: 6
# Median of Response: 0
# Median of Complain: 0

# %%
# mode of response and complain
dict_of_mode={}
for e in listOfKeyVlu:
    if e not in dict_of_mode:
        dict_of_mode[e]=stats.mode(new_df[e])
#mode of keyValues.
for key,value in dict_of_mode.items():
    print(f"Mode of {key}: {value}")
# Out:
# Mode of Income: 7500.0
# Mode of Kidhome: 0
# Mode of Teenhome: 0
# Mode of Recency: 65
# Mode of MntWines: 2
# Mode of MntFruits: 0
# Mode of MntMeatProducts: 11
# Mode of MntFishProducts: 0
# Mode of MntSweetProducts: 0
# Mode of MntGoldProds: 3
# Mode of NumDealsPurchases: 1
# Mode of NumWebPurchases: 1
# Mode of NumCatalogPurchases: 0
# Mode of NumStorePurchases: 3
# Mode of NumWebVisitsMonth: 7
# Mode of Response: 0
# Mode of Complain: 0

# %%
# Variance
dict_of_variance={}
for e in listOfKeyVlu:
    if e not in dict_of_variance:
        dict_of_variance[e]=stats.variance(new_df[e])
#mode of keyValues.
for key,value in dict_of_variance.items():
    print(f"variance of {key}: {value}")
# Out:
# variance of Income: 370974317.4350586
# variance of Kidhome: 0.28969570820609497
# variance of Teenhome: 0.2931404635508672
# variance of Recency: 839.4473936865425
# variance of MntWines: 104627.52364693693
# variance of MntFruits: 808.4278830426441
# variance of MntMeatProducts: 30468.09672702596
# variance of MntFishProducts: 1625.153220100695
# variance of MntSweetProducts: 890.1792566084071
# variance of MntGoldProds: 1853.672693466985
# variance of NumDealsPurchases: 2.392584951105471
# variance of NumWebPurchases: 6.855755434542801
# variance of NumCatalogPurchases: 6.470212147631503
# variance of NumStorePurchases: 10.117068427995637
# variance of NumWebVisitsMonth: 4.708210659570227
# variance of Response: 0.1137727830853992
# variance of Complain: 0

# %%
dict_of_std={}
for e in listOfKeyVlu:
    if e not in dict_of_std:
        dict_of_std[e]=stats.stdev(new_df[e])
#mode of keyValues.
for key,value in dict_of_std.items():
    print(f"Standard deviation of {key}: {value}")
# Out:
# Standard deviation of Income: 19260.693586552345
# Standard deviation of Kidhome: 0.5382338787238267
# Standard deviation of Teenhome: 0.5414244763130562
# Standard deviation of Recency: 28.973218559327204
# Standard deviation of MntWines: 323.46178081333954
# Standard deviation of MntFruits: 28.432866247401865
# Standard deviation of MntMeatProducts: 174.5511292631072
# Standard deviation of MntFishProducts: 40.313189158148916
# Standard deviation of MntSweetProducts: 29.835871976672763
# Standard deviation of MntGoldProds: 43.05429936100441
# Standard deviation of NumDealsPurchases: 1.5467982903744983
# Standard deviation of NumWebPurchases: 2.6183497540517386
# Standard deviation of NumCatalogPurchases: 2.543661169973608
# Standard deviation of NumStorePurchases: 3.180733944861726
# Standard deviation of NumWebVisitsMonth: 2.169841159986193
# Standard deviation of Response: 0.3373022132826869
# Standard deviation of Complain: 0.0

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# ## Binomial Distribution

# %%
df.head()
# Out:
#       Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826 1970-01-01  Graduation       Divorced  84835.0        0         0
# 1      1 1961-01-01  Graduation         Single  57091.0        0         0
# 2  10476 1958-01-01  Graduation        Married  67267.0        0         1
# 5   7348 1958-01-01         PhD         Single  71691.0        0         0
# 6   4073 1954-01-01    2n Cycle        Married  63564.0        0         0
#
#   Dt_Customer  Recency  MntWines  ...  MntSweetProducts  MntGoldProds  \
# 0  2014-06-16        0       189  ...               189           218
# 1  2014-06-15        0       464  ...                 0            37
# 2  2014-05-13        0       134  ...                 2            30
# 5  2014-03-17        0       336  ...                32            43
# 6  2014-01-29        0       769  ...                34            65
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ...

# %%
n=len(df)
prob_res=(df['Response']==1).sum()/n
prob_com=(df['Complain']==1).sum()/n

# %%
# probability.

print(prob_res*100)
print(prob_com*100)
# Out:
# 15.179252479023647
# 0.9153318077803204

# %%
from scipy.stats import binom
n=len(df)
p1=prob_res
p2=prob_com
prob1=binom.pmf(1,n,p1)
prob2=binom.pmf(1,n,p2)
print(prob1)
print(prob2)
# Out:
# 4.331100433973503e-92
# 7.04114094293711e-05

# %% [markdown]
# ## Normal Distribution

# %%
print(dict_of_std['Income'])
# Out:
# 19260.693586552345

# %%
# probablities
from scipy.stats import norm
mean=dict_of_mean['Income']
std=dict_of_std['Income']
x=np.linspace(mean-4*std,mean+4*std,1000)
y=norm(loc=mean,scale=std).pdf(x)
plt.plot(x,y)
plt.axvline(mean,ls='--')
plt.show()

# %%
cdf=norm.cdf(x,mean,std)
plt.plot(x,cdf)
plt.title('Normal Cumulative Distribution Function')
plt.xlabel('X')
plt.ylabel("f(X)")
plt.show()

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %%
# Total expenditure in last two years.
new_df['Expenditure']=new_df['MntWines']+new_df['MntFruits']+new_df[
       'MntMeatProducts']+new_df['MntFishProducts']+new_df['MntSweetProducts']+new_df[
       'MntGoldProds']

# %%
new_df.head()
# Out:
#        Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 1       1 1961-01-01  Graduation         Single  57091.0        0         0
# 2   10476 1958-01-01  Graduation        Married  67267.0        0         1
# 6    4073 1954-01-01    2n Cycle        Married  63564.0        0         0
# 7    1991 1967-01-01  Graduation       Together  44931.0        0         1
# 10   2079 1947-01-01    2n Cycle        Married  81044.0        0         0
#
#    Dt_Customer  Recency  MntWines  ...  MntGoldProds  NumDealsPurchases  \
# 1   2014-06-15        0       464  ...            37                  1
# 2   2014-05-13        0       134  ...            30                  1
# 6   2014-01-29        0       769  ...            65                  1
# 7   2014-01-18        0        78  ...             7                  1
# 10  2013-12-27        0       450  ...            26                  1
#
#     NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ...

# %% [markdown]
# ## segment of customer which has heighest income by education

# %%
# ploting bar graph.
sns.barplot(x='Education',y='Income',data=new_df)
plt.xlabel('Education')
plt.ylabel('Income')
plt.title('Heighest income by Education')
plt.show()

# %% [markdown]
# So we can clearly see here as we go from basic education to heighest education Income increases.

# %% [markdown]
# ## now expenditure according to education.

# %%
sns.barplot(x='Education',y='Expenditure',data=new_df)
plt.xlabel('Education')
plt.ylabel('Expenditure')
plt.title('Heighest Expenditure by Education')
plt.show()

# %% [markdown]
# So we can clearly see here as we go from basic education to heighest education expenditure increases.

# %% [markdown]
# ## Trend line to show relationship between age and expenditure of the costomers.

# %%
sns.lineplot(x=np.array(new_df['Age']),y=np.array(new_df['Expenditure']))
plt.xlabel('Age')
plt.ylabel('Expenditure')
plt.title('Heighest Expenditure by Age')
plt.show()

# %% [markdown]
# So we can see that relationship between age and expenditure as age increases expenditure also increases.

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %%
sns.lineplot(x=np.array(new_df['Age']),y=np.array(new_df['Expenditure']))
plt.xlabel('Age')
plt.ylabel('Expenditure')
plt.title('Heighest Expenditure by Age')
plt.show()

# %% [markdown]
# From the above chart we can clearly visualise that there is increasing trend in expenditure as age of the customer increases.
# show it is recomended to target or lounch campaigns to target teenagers and the older customers.

# %%
sns.barplot(x='Education',y='Expenditure',data=new_df)
plt.xlabel('Education')
plt.ylabel('Expenditure')
plt.title('Heighest Expenditure by Education')
plt.show()

# %% [markdown]
# From the above graph we can clearly see that the customer have heighest education i.e. phd expend more so it will be more usefull to target this categories.

# %%
sns.barplot(x='Marital_Status',y='Expenditure',data=new_df)
plt.xlabel('Education')
plt.ylabel('Expenditure')
plt.title('Heighest Expenditure by mertial status')
plt.show()

# %% [markdown]
# It is clear that Married cuples and Divorced category custmers expend more then other categories. And Alone has the lowest Expenditure.

# %%
sns.barplot(x='Marital_Status',y='MntGoldProds',data=new_df)
plt.xlabel('Education')
plt.ylabel('Expenditure in Gold')
plt.title('Heighest Expenditure in Gold by maretial status')
plt.show()

# %% [markdown]
# So it is clear educated widow expend more in gold then Divorced and then YOLO class people.

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
