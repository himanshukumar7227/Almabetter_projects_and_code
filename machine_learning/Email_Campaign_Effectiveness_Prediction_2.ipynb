# %% [markdown]
# # **Project Name**    - Email Campaign Effectiveness Prediction

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# First of all we have a data related to Email Campaign. Our business objective is to create a Machine Learning Model that will predict an email can be ignored, read or acknowledged by the customer. For this project at first we had to import some python libraries. We imported pandas and numpy for data manipulation, matplotlib and seaborn from visualization and so many sklearn sub-libraries for model building. After that we imported out dataset. By the help of this past data we had created our model. Then we cleand our data. Then we took some insight from this data like by the help of visualization. Then we used dist plot, bar plot, heatmap plot, scatter plot etc for the visualization. After that we had started our model building. Then we had to work on our data because model can not read text data. For this we changed our categorical values to numrical. Our data set was not balanced so we used over sampeling method for balancing it. After that we got our final data which is maching readable format. Then We create 3 models which are Logistic Regression, Decition Tree and XGBoost respectively.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The main objective of this project is to create a machine learning model to characterize the mail and track the mail that is ignored; read; acknowledged by the reader.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/e2/7b/8c1b410cd0604cee9a167a19f7e1746f5b92ae7d02ad574ab560b73c5a48/xgboost-2.1.1-py3-none-win_amd64.whl.metadata
#   Downloading xgboost-2.1.1-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.10.1)
# Downloading xgboost-2.1.1-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB 1.3 MB/s eta 0:01:38
#    --------------------------------------- 0.1/124.9 MB 648.1 kB/s eta 0:03:13
#    --------------------------------------- 0.1/124.9 MB 508.4 kB/s eta 0:04:06
#    --------------------------------------- 0.1/124.9 MB 521.8 kB/s eta 0:04:00
#    --------------------------------------- 0.1/124.9 MB 479.3 kB/s eta 0:04:21
#    --------------------------------------- 0.2/124.9 MB 544.7 kB/s eta 0:03:50
4 MB/s eta 0:00:28
#    ---------- ----------------------------- 32.7/124.9 MB 3.4 MB/s eta 0:00:28
#    ---------- ----------------------------- 32.7/124.9 MB 3.4 MB/s eta 0:00:28
#    ---------- ----------------------------- 32.7/124.9 MB 3.4 MB/s eta 0:00:28
#    ---------- ----------------------------- 32.7/124.9 MB 3.4 MB/s eta 0:00:28
#    ---------- ----------------------------- 32.7/124.9 MB 3.4 MB/s eta 0:00:28
#    ---------- ----------------------------- 32.7/124.9 MB 3.4 MB/s eta 0:00:28
#    ---------- ----------------------------- 32.7/124.9 MB 2.8 MB/s eta 0:00:33
#    ---------- ----------------------------- 32.9/124.9 MB 2.8 MB/s eta 0:00:34
#    ---------- ----------------------------- 33.1/124.9 MB 2.8 MB/s eta 0:00:34
#    ---------- ----------------------------- 33.3/124.9 MB 2.8 MB/s eta 0:00:34
#    ---------- ----------------------------- 33.4/124.9 MB 2.7 MB/s eta 0:00:34
#    ---------- ----------------------------- 33.5/124.9 MB 2.7 MB/s eta 0:00:34
#    ---------- ----------------------------- 33.6/124.9 MB 2.7 MB/s eta 0:00:34
#    ---------- ----------------------------- 33.8/124.9 MB 2.7 MB/s eta 0:00:34
#    ---------- ----------------------------- 33.9/124.9 MB 2.7 MB/s eta 0:00:34
#    ---------- ----------------------------- 33.9/124.9 MB 2.7 MB/s eta 0:00:35
#    ---------- ----------------------------- 34.1/124.9 MB 2.7 MB/s eta 0:00:35
#    ---------- ----------------------------- 34.3/124.9 MB 2.7 MB/s eta 0:00:35
#    ----------- ---------------------------- 34.4/124.9 MB 2.7 MB/s eta 0:00:34
#    ----------- ---------------------------- 34.5/124.9 MB 2.7 MB/s eta 0:00:34
#    ----------- ---------------------------- 34.7/124.9 MB 2.7 MB/s eta 0:00:34
#    ----------- ---------------------------- 34.9/124.9 MB 2.7 MB/s eta 0:00:34
#    ----------- ---------------------------- 35.1/124.9 MB 2.7 MB/s eta 0:00:34
#    ----------- ---------------------------- 35.3/124.9 MB 2.7 MB/s eta 0:00:34
#    ----------- ---------------------------- 35.4/124.9 MB 2.7 MB/s eta 0:00:34
#    ----------- ---------------------------- 35.6/124.9 MB 2.7 MB/s eta 0:00:34
#    ----------- ---------------------------- 35.7/124.9 MB 2.7 MB/s eta 0:00:34
#    ----------- ---------------------------- 35.9/124.9 MB 2.6 MB/s eta 0:00:34
#    ----------- ---------------------------- 36.1/124.9 MB 2.6 MB/s eta 0:00:34
#    ----------- ---------------------------- 36.2/124.9 MB 2.6 MB/s eta 0:00:34
#    ----------- ---------------------------- 36.3/124.9 MB 2.6 MB/s eta 0:00:34
#    ----------- ---------------------------- 36.4/124.9 MB 2.6 MB/s eta 0:00:35
#    ----------- ---------------------------- 36.4/124.9 MB 2.6 MB/s eta 0:00:35
#    ----------- ---------------------------- 36.5/124.9 MB 2.6 MB/s eta 0:00:35
#    ----------- ---------------------------- 36.5/124.9 MB 2.5 MB/s eta 0:00:35
#    ----------- ---------------------------- 36.5/124.9 MB 2.5 MB/s eta 0:00:35
#    ----------- ---------------------------- 36.6/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 36.6/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 36.7/124.9 MB 2.4 MB/s eta 0:00:37
#    ----------- ---------------------------- 36.8/124.9 MB 2.4 MB/s eta 0:00:37
#    ----------- ---------------------------- 36.9/124.9 MB 2.4 MB/s eta 0:00:37
#    ----------- ---------------------------- 37.0/124.9 MB 2.4 MB/s eta 0:00:37
#    ----------- ---------------------------- 37.1/124.9 MB 2.4 MB/s eta 0:00:37
#    ----------- ---------------------------- 37.1/124.9 MB 2.4 MB/s eta 0:00:37
#    ----------- ---------------------------- 37.2/124.9 MB 2.4 MB/s eta 0:00:38
#    ----------- ---------------------------- 37.3/124.9 MB 2.3 MB/s eta 0:00:38
#    ----------- ---------------------------- 37.3/124.9 MB 2.3 MB/s eta 0:00:38
#    ----------- ---------------------------- 37.4/124.9 MB 2.3 MB/s eta 0:00:38
#    ----------- ---------------------------- 37.4/124.9 MB 2.3 MB/s eta 0:00:38
#    ------------ --------------------------- 37.5/124.9 MB 2.3 MB/s eta 0:00:39
#    ------------ --------------------------- 37.6/124.9 MB 2.3 MB/s eta 0:00:39
#    ------------ --------------------------- 37.9/124.9 MB 2.3 MB/s eta 0:00:39
#    ------------ --------------------------- 38.0/124.9 MB 2.3 MB/s eta 0:00:39
#    ------------ --------------------------- 38.1/124.9 MB 2.3 MB/s eta 0:00:39
#    ------------ --------------------------- 38.3/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 38.4/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 38.6/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 38.8/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 39.0/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 39.2/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 39.3/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 39.4/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 39.4/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 39.6/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 39.8/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------ --------------------------- 40.1/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------ --------------------------- 40.2/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------ --------------------------- 40.4/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------ --------------------------- 40.6/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 40.8/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 40.9/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 41.1/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 41.2/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 41.4/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 41.5/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 41.6/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 41.7/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 41.8/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 41.8/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 41.9/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 42.0/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 42.1/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 42.2/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------- -------------------------- 42.3/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------- -------------------------- 42.5/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------- -------------------------- 42.6/124.9 MB 2.2 MB/s eta 0:00:39
#    ------------- -------------------------- 42.8/124.9 MB 2.2 MB/s eta 0:00:38
#    ------------- -------------------------- 42.9/124.9 MB 2.2 MB/s eta 0:00:37
#    ------------- -------------------------- 43.0/124.9 MB 2.6 MB/s eta 0:00:32
#    ------------- -------------------------- 43.2/124.9 MB 2.6 MB/s eta 0:00:32
#    ------------- -------------------------- 43.3/124.9 MB 2.6 MB/s eta 0:00:31
#    ------------- -------------------------- 43.4/124.9 MB 2.6 MB/s eta 0:00:32
#    ------------- -------------------------- 43.6/124.9 MB 2.6 MB/s eta 0:00:31
#    -------------- ------------------------- 43.7/124.9 MB 2.7 MB/s eta 0:00:31
#    -------------- ------------------------- 43.9/124.9 MB 2.7 MB/s eta 0:00:31
#    -------------- ------------------------- 44.1/124.9 MB 2.7 MB/s eta 0:00:31
#    -------------- ------------------------- 44.2/124.9 MB 2.7 MB/s eta 0:00:31
#    -------------- ------------------------- 44.4/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 44.5/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 44.7/124.9 MB 2.7 MB/s eta 0:00:31
#    -------------- ------------------------- 44.9/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 45.0/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 45.1/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 45.3/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 45.5/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 45.6/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 45.8/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 45.9/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 46.1/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 46.2/124.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 46.2/124.9 MB 2.6 MB/s eta 0:00:30
#    -------------- ------------------------- 46.2/124.9 MB 2.6 MB/s eta 0:00:31
#    -------------- ------------------------- 46.3/124.9 MB 2.6 MB/s eta 0:00:31
#    -------------- ------------------------- 46.3/124.9 MB 2.5 MB/s eta 0:00:31
#    -------------- ------------------------- 46.3/124.9 MB 2.5 MB/s eta 0:00:31
#    -------------- ------------------------- 46.4/124.9 MB 2.5 MB/s eta 0:00:32
#    -------------- ------------------------- 46.4/124.9 MB 2.5 MB/s eta 0:00:32
#    -------------- ------------------------- 46.4/124.9 MB 2.4 MB/s eta 0:00:33
#    -------------- ------------------------- 46.4/124.9 MB 2.4 MB/s eta 0:00:33
#    -------------- ------------------------- 46.5/124.9 MB 2.4 MB/s eta 0:00:33
#    -------------- ------------------------- 46.5/124.9 MB 2.4 MB/s eta 0:00:33
#    -------------- ------------------------- 46.5/124.9 MB 2.4 MB/s eta 0:00:33
#    -------------- ------------------------- 46.5/124.9 MB 2.4 MB/s eta 0:00:33
#    -------------- ------------------------- 46.5/124.9 MB 2.4 MB/s eta 0:00:33
#    -------------- ------------------------- 46.5/124.9 MB 2.4 MB/s eta 0:00:33
#    -------------- ------------------------- 46.5/124.9 MB 2.4 MB/s eta 0:00:33
#    -------------- ------------------------- 46.7/124.9 MB 2.3 MB/s eta 0:00:34
#    --------------- ------------------------ 46.9/124.9 MB 2.4 MB/s eta 0:00:33
#    --------------- ------------------------ 47.5/124.9 MB 2.6 MB/s eta 0:00:31
#    --------------- ------------------------ 47.6/124.9 MB 2.6 MB/s eta 0:00:30
#    --------------- ------------------------ 47.8/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 47.9/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 48.1/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 48.3/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 48.5/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 48.6/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 48.7/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 48.8/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 48.9/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 49.0/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 49.2/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 49.4/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 49.5/124.9 MB 2.6 MB/s eta 0:00:29
#    --------------- ------------------------ 49.6/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 49.7/124.9 MB 2.7 MB/s eta 0:00:29
#    --------------- ------------------------ 49.9/124.9 MB 2.7 MB/s eta 0:00:29
#    ---------------- ----------------------- 50.0/124.9 MB 2.6 MB/s eta 0:00:29
#    ---------------- ----------------------- 50.1/124.9 MB 2.6 MB/s eta 0:00:29
#    ---------------- ----------------------- 50.2/124.9 MB 2.6 MB/s eta 0:00:29
#    ---------------- ----------------------- 50.2/124.9 MB 2.6 MB/s eta 0:00:29
#    ---------------- ----------------------- 50.4/124.9 MB 2.6 MB/s eta 0:00:29
#    ---------------- ----------------------- 50.4/124.9 MB 2.6 MB/s eta 0:00:30
#    ---------------- ----------------------- 50.6/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 50.7/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 50.8/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 50.9/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.0/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.1/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.2/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.4/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.5/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.6/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.6/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.8/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.9/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.0/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.0/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.1/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.2/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.3/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.4/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.5/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.6/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.8/124.9 MB 2.5 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.8/124.9 MB 2.4 MB/s eta 0:00:30
#    ---------------- ----------------------- 52.9/124.9 MB 2.4 MB/s eta 0:00:30
#    ---------------- ----------------------- 53.0/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 53.1/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 53.2/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 53.3/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 53.5/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 53.5/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 53.7/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 53.7/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 53.9/124.9 MB 2.4 MB/s eta 0:00:31
#    ----------------- ---------------------- 54.0/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 54.2/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 54.3/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 54.5/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 54.6/124.9 MB 2.3 MB/s eta 0:00:30
#    ----------------- ---------------------- 54.7/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 54.8/124.9 MB 2.3 MB/s eta 0:00:30
#    ----------------- ---------------------- 55.0/124.9 MB 2.3 MB/s eta 0:00:30
#    ----------------- ---------------------- 55.1/124.9 MB 2.3 MB/s eta 0:00:30
#    ----------------- ---------------------- 55.3/124.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 55.4/124.9 MB 2.3 MB/s eta 0:00:30
#    ----------------- ---------------------- 55.6/124.9 MB 2.3 MB/s eta 0:00:30
#    ----------------- ---------------------- 55.7/124.9 MB 2.3 MB/s eta 0:00:30
#    ----------------- ---------------------- 55.8/124.9 MB 2.3 MB/s eta 0:00:30
#    ----------------- ---------------------- 56.0/124.9 MB 2.3 MB/s eta 0:00:30
#    ----------------- ---------------------- 56.0/124.9 MB 2.3 MB/s eta 0:00:30
#    ----------------- ---------------------- 56.1/124.9 MB 2.3 MB/s eta 0:00:30
#    ------------------ --------------------- 56.4/124.9 MB 2.3 MB/s eta 0:00:30
#    ------------------ --------------------- 56.5/124.9 MB 2.4 MB/s eta 0:00:29
#    ------------------ --------------------- 56.6/124.9 MB 2.5 MB/s eta 0:00:28
#    ------------------ --------------------- 56.8/124.9 MB 2.8 MB/s eta 0:00:25
#    ------------------ --------------------- 56.9/124.9 MB 2.8 MB/s eta 0:00:25
#    ------------------ --------------------- 57.1/124.9 MB 2.7 MB/s eta 0:00:25
#    ------------------ --------------------- 57.3/124.9 MB 2.7 MB/s eta 0:00:26
#    ------------------ --------------------- 57.4/124.9 MB 2.7 MB/s eta 0:00:26
#    ------------------ --------------------- 57.5/124.9 MB 2.6 MB/s eta 0:00:26
#    ------------------ --------------------- 57.6/124.9 MB 2.6 MB/s eta 0:00:26
#    ------------------ --------------------- 57.8/124.9 MB 2.6 MB/s eta 0:00:26
#    ------------------ --------------------- 58.0/124.9 MB 2.6 MB/s eta 0:00:26
#    ------------------ --------------------- 58.0/124.9 MB 2.6 MB/s eta 0:00:26
#    ------------------ --------------------- 58.1/124.9 MB 2.6 MB/s eta 0:00:26
#    ------------------ --------------------- 58.2/124.9 MB 2.6 MB/s eta 0:00:26
#    ------------------ --------------------- 58.3/124.9 MB 2.5 MB/s eta 0:00:27
#    ------------------ --------------------- 58.3/124.9 MB 2.5 MB/s eta 0:00:27
#    ------------------ --------------------- 58.4/124.9 MB 2.5 MB/s eta 0:00:27
#    ------------------ --------------------- 58.4/124.9 MB 2.5 MB/s eta 0:00:27
#    ------------------ --------------------- 58.4/124.9 MB 2.5 MB/s eta 0:00:28
#    --------------------- ------------------ 67.0/124.9 MB 2.4 MB/s eta 0:00:25
#    --------------------- ------------------ 67.1/124.9 MB 2.3 MB/s eta 0:00:25
#    --------------------- ------------------ 67.3/124.9 MB 2.4 MB/s eta 0:00:25
#    --------------------- ------------------ 67.5/124.9 MB 2.3 MB/s eta 0:00:25
#    --------------------- ------------------ 67.6/124.9 MB 2.4 MB/s eta 0:00:25
#    --------------------- ------------------ 67.8/124.9 MB 2.4 MB/s eta 0:00:25
# ...
#    ------------------------------- -------- 99.0/124.9 MB 2.7 MB/s eta 0:00:10
#    ------------------------------- -------- 99.0/124.9 MB 2.7 MB/s eta 0:00:10
#    ------------------------------- -------- 99.0/124.9 MB 2.7 MB/s eta 0:00:10
#    ------------------------------- -------- 99.1/124.9 MB 2.7 MB/s eta 0:00:10
#    ------------------------------- -------- 99.1/124.9 MB 2.6 MB/s eta 0:00:10
#    ------------------------------- -------- 99.1/124.9 MB 2.6 MB/s eta 0:00:10
#    ------------------------------- -------- 99.2/124.9 MB 2.6 MB/s eta 0:00:10
#    ------------------------------- -------- 99.2/124.9 MB 2.6 MB/s eta 0:00:10
#    ------------------------------- -------- 99.2/124.9 MB 2.6 MB/s eta 0:00:11
#    ------------------------------- -------- 99.3/124.9 MB 2.5 MB/s eta 0:00:11
#    ------------------------------- -------- 99.3/124.9 MB 2.5 MB/s eta 0:00:11
#    ------------------------------- -------- 99.5/124.9 MB 2.5 MB/s eta 0:00:11
#    ------------------------------- -------- 99.5/124.9 MB 2.5 MB/s eta 0:00:11
#    ------------------------------- -------- 99.7/124.9 MB 2.5 MB/s eta 0:00:11
#    ------------------------------- -------- 99.8/124.9 MB 2.5 MB/s eta 0:00:11
#    ------------------------------- -------- 99.9/124.9 MB 2.5 MB/s eta 0:00:10
#    ------------------------------- ------- 100.0/124.9 MB 2.5 MB/s eta 0:00:11
#    ------------------------------- ------- 100.1/124.9 MB 2.5 MB/s eta 0:00:10
#    ------------------------------- ------- 100.3/124.9 MB 2.6 MB/s eta 0:00:10
#    ------------------------------- ------- 100.5/124.9 MB 2.6 MB/s eta 0:00:10
#    ------------------------------- ------- 100.6/124.9 MB 2.7 MB/s eta 0:00:10
#    ------------------------------- ------- 100.8/124.9 MB 2.7 MB/s eta 0:00:09
#    ------------------------------- ------- 101.0/124.9 MB 2.8 MB/s eta 0:00:09
#    ------------------------------- ------- 101.1/124.9 MB 2.8 MB/s eta 0:00:09
#    ------------------------------- ------- 101.2/124.9 MB 2.8 MB/s eta 0:00:09
#    ------------------------------- ------- 101.4/124.9 MB 2.7 MB/s eta 0:00:09
#    ------------------------------- ------- 101.5/124.9 MB 2.7 MB/s eta 0:00:09
#    ------------------------------- ------- 101.6/124.9 MB 2.8 MB/s eta 0:00:09
#    ------------------------------- ------- 101.7/124.9 MB 2.8 MB/s eta 0:00:09
#    ------------------------------- ------- 101.9/124.9 MB 2.7 MB/s eta 0:00:09
#    ------------------------------- ------- 102.0/124.9 MB 2.7 MB/s eta 0:00:09
#    ------------------------------- ------- 102.1/124.9 MB 2.7 MB/s eta 0:00:09
#    ------------------------------- ------- 102.2/124.9 MB 2.7 MB/s eta 0:00:09
#    ------------------------------- ------- 102.3/124.9 MB 2.7 MB/s eta 0:00:09
#    ------------------------------- ------- 102.4/124.9 MB 2.7 MB/s eta 0:00:09
#    -------------------------------- ------ 102.6/124.9 MB 2.7 MB/s eta 0:00:09
#    -------------------------------- ------ 102.7/124.9 MB 2.7 MB/s eta 0:00:09
MB 3.1 MB/s eta 0:00:04
#    ----------------------------------- --- 113.2/124.9 MB 3.1 MB/s eta 0:00:04
#    ----------------------------------- --- 113.4/124.9 MB 3.1 MB/s eta 0:00:04
#    ----------------------------------- --- 113.6/124.9 MB 3.1 MB/s eta 0:00:04
#    ----------------------------------- --- 113.9/124.9 MB 3.1 MB/s eta 0:00:04
#    ----------------------------------- --- 114.1/124.9 MB 3.1 MB/s eta 0:00:04
#    ----------------------------------- --- 114.2/124.9 MB 3.2 MB/s eta 0:00:04
#    ----------------------------------- --- 114.4/124.9 MB 3.2 MB/s eta 0:00:04
#    ----------------------------------- --- 114.6/124.9 MB 3.2 MB/s eta 0:00:04
#    ----------------------------------- --- 114.8/124.9 MB 3.2 MB/s eta 0:00:04
#    ----------------------------------- --- 114.9/124.9 MB 3.2 MB/s eta 0:00:04
#    ----------------------------------- --- 115.1/124.9 MB 3.3 MB/s eta 0:00:03
#    ------------------------------------ -- 115.3/124.9 MB 3.3 MB/s eta 0:00:03
#    ------------------------------------ -- 115.5/124.9 MB 3.3 MB/s eta 0:00:03
#    ------------------------------------ -- 115.6/124.9 MB 3.3 MB/s eta 0:00:03
#    ------------------------------------ -- 115.8/124.9 MB 3.3 MB/s eta 0:00:03
#    ------------------------------------ -- 115.8/124.9 MB 3.3 MB/s eta 0:00:03
#    ------------------------------------ -- 115.8/124.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------------------ -- 115.8/124.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------------------ -- 115.9/124.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------------------ -- 115.9/124.9 MB 3.1 MB/s eta 0:00:03
#    ------------------------------------ -- 116.0/124.9 MB 3.1 MB/s eta 0:00:03
#    ------------------------------------ -- 116.0/124.9 MB 3.1 MB/s eta 0:00:03
#    ------------------------------------ -- 116.0/124.9 MB 3.0 MB/s eta 0:00:03
#    ------------------------------------ -- 116.1/124.9 MB 3.0 MB/s eta 0:00:03
#    ------------------------------------ -- 116.1/124.9 MB 3.0 MB/s eta 0:00:03
#    ------------------------------------ -- 116.1/124.9 MB 2.9 MB/s eta 0:00:03
#    ------------------------------------ -- 116.2/124.9 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------ -- 116.2/124.9 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------ -- 116.4/124.9 MB 2.9 MB/s eta 0:00:03
#    ------------------------------------ -- 116.6/124.9 MB 2.9 MB/s eta 0:00:03
#    ------------------------------------ -- 116.7/124.9 MB 2.9 MB/s eta 0:00:03
#    ------------------------------------ -- 116.8/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------ -- 116.9/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------ -- 117.0/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------ -- 117.2/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------ -- 117.4/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------ -- 117.6/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------ -- 117.8/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------ -- 117.9/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------ -- 118.1/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------ -- 118.3/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------ -- 118.4/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------- - 118.5/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------- - 118.5/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------- - 118.7/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------- - 118.9/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------- - 119.2/124.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------- - 119.4/124.9 MB 2.8 MB/s eta 0:00:02
#    ------------------------------------- - 119.6/124.9 MB 2.8 MB/s eta 0:00:02
#    ------------------------------------- - 119.7/124.9 MB 2.8 MB/s eta 0:00:02
#    ------------------------------------- - 119.9/124.9 MB 2.8 MB/s eta 0:00:02
#    ------------------------------------- - 120.0/124.9 MB 2.8 MB/s eta 0:00:02
#    ------------------------------------- - 120.3/124.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- - 120.5/124.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- - 120.6/124.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- - 120.8/124.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- - 121.0/124.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- - 121.1/124.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- - 121.3/124.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- - 121.5/124.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- - 121.7/124.9 MB 2.9 MB/s eta 0:00:02
#    --------------------------------------  121.9/124.9 MB 2.9 MB/s eta 0:00:02
#    --------------------------------------  122.1/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  122.2/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  122.4/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  122.6/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  122.8/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  122.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  123.1/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  123.1/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  123.1/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  123.5/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  123.7/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  123.8/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  123.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.1/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.3/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.5/124.9 MB 2.9 MB/s eta 0:00:01
#    --------------------------------------  124.7/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.8/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------------- 124.9/124.9 MB 2.5 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.1

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
dataset=pd.read_csv('data_email_campaign.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
dataset.head()
# Out:
#             Email_ID  Email_Type  Subject_Hotness_Score  Email_Source_Type  \
# 0  EMA00081000034500           1                    2.2                  2
# 1  EMA00081000045360           2                    2.1                  1
# 2  EMA00081000066290           2                    0.1                  1
# 3  EMA00081000076560           1                    3.0                  2
# 4  EMA00081000109720           1                    0.0                  2
#
#   Customer_Location  Email_Campaign_Type  Total_Past_Communications  \
# 0                 E                    2                       33.0
# 1               NaN                    2                       15.0
# 2                 B                    3                       36.0
# 3                 E                    2                       25.0
# 4                 C                    3                       18.0
#
#    Time_Email_sent_Category  Word_Count  Total_Links  Total_Images  \
# 0                         1         440          8.0           0.0
# 1                         2         504          5.0           0.0
# 2                         2         962          5.0           0.0
# 3                         2         610         16.0           0.0
# 4                         2         947          4.0           0.0
#
#    Email_Status
# 0             0
# 1             0
# 2             1
# 3             0
# 4             0

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
dataset.shape
# Out:
# (68353, 12)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68353 entries, 0 to 68352
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Email_ID                   68353 non-null  object
#  1   Email_Type                 68353 non-null  int64
#  2   Subject_Hotness_Score      68353 non-null  float64
#  3   Email_Source_Type          68353 non-null  int64
#  4   Customer_Location          56758 non-null  object
#  5   Email_Campaign_Type        68353 non-null  int64
#  6   Total_Past_Communications  61528 non-null  float64
#  7   Time_Email_sent_Category   68353 non-null  int64
#  8   Word_Count                 68353 non-null  int64
#  9   Total_Links                66152 non-null  float64
#  10  Total_Images               66676 non-null  float64
#  11  Email_Status               68353 non-null  int64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 6.3+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
dataset.isnull().sum()
# Out:
# Email_ID                         0
# Email_Type                       0
# Subject_Hotness_Score            0
# Email_Source_Type                0
# Customer_Location            11595
# Email_Campaign_Type              0
# Total_Past_Communications     6825
# Time_Email_sent_Category         0
# Word_Count                       0
# Total_Links                   2201
# Total_Images                  1677
# Email_Status                     0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(10,7))
sns.heatmap(dataset.isnull())
plt.title('Visualisation of missing values')
# Out:
# Text(0.5, 1.0, 'Visualisation of missing values')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# From the above analysis we know the following details.
# 1. There are 68353 rows and 12 columns.
# 2. Dataset doesn't contain any duplicate row or column.
# 3. Customer_Location column has 11595,Total_Past_Communications has 6825,Total_Links has 2201 and Total_Images has 1677 null values.
# 4. Here most of the missing values are present in Customer_Location column.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
a=1
for i in dataset.columns:
    print(a,".",i)
    a+=1
# Out:
# 1 . Email_ID
# 2 . Email_Type
# 3 . Subject_Hotness_Score
# 4 . Email_Source_Type
# 5 . Customer_Location
# 6 . Email_Campaign_Type
# 7 . Total_Past_Communications
# 8 . Time_Email_sent_Category
# 9 . Word_Count
# 10 . Total_Links
# 11 . Total_Images
# 12 . Email_Status

# %%
# Dataset Describe
dataset.describe()
# Out:
#          Email_Type  Subject_Hotness_Score  Email_Source_Type  \
# count  68353.000000           68353.000000       68353.000000
# mean       1.285094               1.095481           1.456513
# std        0.451462               0.997578           0.498109
# min        1.000000               0.000000           1.000000
# 25%        1.000000               0.200000           1.000000
# 50%        1.000000               0.800000           1.000000
# 75%        2.000000               1.800000           2.000000
# max        2.000000               5.000000           2.000000
#
#        Email_Campaign_Type  Total_Past_Communications  \
# count         68353.000000               61528.000000
# mean              2.272234                  28.933250
# std               0.468680                  12.536518
# min               1.000000                   0.000000
# 25%               2.000000                  20.000000
# 50%               2.000000                  28.000000
# 75%               3.000000                  38.000000
# max               3.000000                  67.000000
#
#        Time_Email_sent_Category    Word_Count   Total_Links  Total_Images  \
# count              68353.000000  68353.000000  66152.000000  66676.000000
# mean                   1.999298    699.931751     10.429526      3.550678
# std                    0.631103    271.719440      6.383270      5.596983
# min                    1.000000     40.000000      1.000000      0.000000
# 25%                    2.000000    521.000000      6.000000      0.000000
# 50%                    2.000000    694.000000      9.000000      0.000000
# 75%                    2.000000    880.000000     14.000000      5.000000
# max                    3.000000   1316.000000     49.000000     45.000000
#
#        Email_Status
# count  68353.000000
# mean       0.230934
# std        0.497032
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        2.000000

# %%
categorical= dataset.dtypes[dataset.dtypes=='object'].index
print(categorical)
dataset[categorical].describe()
# Out:
# Index(['Email_ID', 'Customer_Location'], dtype='object')
#                  Email_ID Customer_Location
# count               68353             56758
# unique              68353                 7
# top     EMA00081000034500                 G
# freq                    1             23173

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. Email_ID :- Emails unique Id.
# 2. Email_Type:- Type of email (1= marketing emails 2=important updates).
# 3. Subject_Hotness_Score:- It's the email's subject's score on the basis of how good or effective content is.
# 4. Email_Source_Type:- It's email source type (1=sales and markating 2= important admin mails).
# 5. Customer_Location:- Location of the customer.
# 6. Email_Campaign_Type:- Email campaign type.(1,2,3)
# 7. Total_Past_Communications:- Total previous mails from same sorouce.
# 8. Time_Email_sent_Category:- Time email is being sent(1=morning, 2= evening, 3= night)
# 9. Word_Count:- word counts in the mail.
# 10. Total_Links:- total links present in the mail.
# 11. Total_Images:- Total images present in the mail.
# 12. **Email_Status:- Our Target variable whether mail was 0= ignored, 1= read, 2= acknowledged by the user.**

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
